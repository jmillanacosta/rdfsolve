# %% [markdown]
# # Turn the chemical table into RDF
#
# Use the chemical names and identifiers saved in the [thyroid exploration](AOPWiki_hydration.ipynb).

# %% [markdown]
# ## Open the table

# %%
import pandas as pd
from rdfsolve.client_api import Client

data = Client.from_session("thyroid-session.json")
table = pd.read_csv("thyroid-chemicals.csv")
table
# Out:
#                                   Name  \
# 0                  Triphenyl phosphate
# 1                            Thiazopyr
# 2   2,2',4,4'-Tetrahydroxybenzophenone
# 3                             Clonixin
# 4                        Phenobarbital
# 5                6-Propyl-2-thiouracil
# 6                            Triclopyr
# 7                          Methimazole
# 8                    Meclofenamic acid
# 9      3,3',5,5'-Tetrabromobisphenol A
# 10                   Ethylene thiourea
#
#                                  Identifier
# 0      https://identifiers.org/cas/115-86-6
# 1   https://identifiers.org/cas/117718-60-2
# 2      https://identifiers.org/cas/131-55-5
# 3    https://identifiers.org/cas/17737-65-4
# 4       https://identifiers.org/cas/50-06-6
# 5       https://identifiers.org/cas/51-52-5
# 6    https://identifiers.org/cas/55335-06-3
# 7       https://identifiers.org/cas/60-56-0
# 8      https://identifiers.org/cas/644-62-2
# 9       https://identifiers.org/cas/79-94-7
# 10      https://identifiers.org/cas/96-45-7

# %% [markdown]
# ## Say which columns to use
#
# “Identifier” identifies each chemical. “Name” supplies its title.

# %%
chemicals = data.from_table(
    "Chemical entity", table, id_column="Identifier", title="Name"
)
chemicals
# Out:
# 11 matches
#                               Name            Type
#                Triphenyl phosphate chemical entity
#                          Thiazopyr chemical entity
# 2,2',4,4'-Tetrahydroxybenzophenone chemical entity
#                           Clonixin chemical entity
#                      Phenobarbital chemical entity
#              6-Propyl-2-thiouracil chemical entity
#                          Triclopyr chemical entity
#                        Methimazole chemical entity
#                  Meclofenamic acid chemical entity
#    3,3',5,5'-Tetrabromobisphenol A chemical entity
#                  Ethylene thiourea chemical entity

# %% [markdown]
# ## Save the records

# %%
data.save("chemicals-from-table.ttl", chemicals)
data.close()

# %% [markdown]
# ## Look up a chemical in the new file

# %%
local = Client.from_session(
    "thyroid-session.json", data_file="chemicals-from-table.ttl"
)
local.find("Phenobarbital")
# Out:
# 1 matches
#          Name            Type
# Phenobarbital chemical entity

# %%
local.close()
