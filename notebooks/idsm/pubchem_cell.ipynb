# %% [markdown]
# # RDFSolve: PubChem Cell Analysis
#
# This notebook analyzes the PubChem Cell graph using RDFSolve:
# - **Graph URI**: http://rdf.ncbi.nlm.nih.gov/pubchem/cell
# - **SPARQL Endpoint**: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# - **Dataset**: PubChem Cell
#
# Explore the structure and schema of the PubChem Cell dataset.

# %%
import pandas as pd
from rdfsolve.rdfsolve import RDFSolver
from rdfsolve.void_parser import VoidParser
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Configure Dataset Parameters

# %%
# PubChem Cell configuration
endpoint_url = "https://idsm.elixir-czech.cz/sparql/endpoint/idsm"
graph_uri = "http://rdf.ncbi.nlm.nih.gov/pubchem/cell"
void_iri = "http://rdf.ncbi.nlm.nih.gov/pubchem/cell"
dataset_name = "pubchem_cell"
working_path = "."

print(f"Dataset: {dataset_name}")
print(f"Endpoint: {endpoint_url}")
print(f"Graph URI: {graph_uri}")
print(f"VoID IRI: {void_iri}")
# Out:
# Dataset: pubchem_cell
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/cell
# VoID IRI: http://rdf.ncbi.nlm.nih.gov/pubchem/cell

# %% [markdown]
# ## Step 2: Initialize RDFSolver

# %%
try:
    solver = RDFSolver(
        endpoint=endpoint_url,
        path=working_path,
        void_iri=void_iri,
        dataset_name=dataset_name
    )
    
    print("RDFSolver initialized successfully")
    print(f"Endpoint: {solver.endpoint}")
    print(f"Dataset: {solver.dataset_name}")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# RDFSolver initialized successfully
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Dataset: pubchem_cell

# %% [markdown]
# ## Step 3: Generate VoID Description

# %%
try:
    print("Generating VoID description...")
    
    void_graph = solver.void_generator(
        graph_uri=graph_uri,
        output_file=f"{dataset_name}_void.ttl",
        counts=True
    )
    
    print(f"VoID generation completed!")
    print(f"Graph contains {len(void_graph)} triples")
    print(f"Saved to: {dataset_name}_void.ttl")
    
except Exception as e:
    print(f"VoID generation failed: {e}")
# Out:
# Generating VoID description...
# Generating VoID from endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Using graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/cell
# Starting query: class_partitions
# Finished query: class_partitions (took 0.44s)
# Starting query: property_partitions
# Finished query: class_partitions (took 0.44s)
# Starting query: property_partitions
# Finished query: property_partitions (took 0.20s)
# Starting query: datatype_partitions
# Finished query: property_partitions (took 0.20s)
# Starting query: datatype_partitions
# Finished query: datatype_partitions (took 0.31s)
# VoID description saved to pubchem_cell_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 70 triples
# Saved to: pubchem_cell_void.ttl
# Finished query: datatype_partitions (took 0.31s)
# VoID description saved to pubchem_cell_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 70 triples
# Saved to: pubchem_cell_void.ttl

# %% [markdown]
# ## Step 4: Extract Schema

# %%
try:
    print("Extracting schema from VoID...")
    parser = VoidParser(void_graph)
    
    schema_df = parser.to_schema(filter_void_nodes=True)
    
    print("Schema extraction completed")
    print(f"Total schema triples: {len(schema_df)}")
    print(f"Unique classes: {schema_df['subject_class'].nunique()}")
    print(f"Unique properties: {schema_df['property'].nunique()}")
    
except Exception as e:
    print(f"Schema extraction failed: {e}")
# Out:
# Extracting schema from VoID...
# Schema extraction completed
# Total schema triples: 16
# Unique classes: 2
# Unique properties: 8

# %% [markdown]
# ## Step 5: Schema Visualization

# %%
# Display schema sample
if 'schema_df' in locals():
    print("Schema Sample (first 10 rows):")
    display(schema_df.head(10))
    
    print("\nTop 10 Classes by Property Count:")
    class_counts = schema_df['subject_class'].value_counts().head(10)
    for cls, count in class_counts.items():
        print(f"  {cls}: {count} properties")
# Out:
# Schema Sample (first 10 rows):
#   subject_class                                        subject_uri  \
# 0          Cell  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 1    SIO_010054     http://semanticscience.org/resource/SIO_010054
# 2          Cell  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 3    SIO_010054     http://semanticscience.org/resource/SIO_010054
# 4    SIO_010054     http://semanticscience.org/resource/SIO_010054
# 5          Cell  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 6    SIO_010054     http://semanticscience.org/resource/SIO_010054
# 7          Cell  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 8    SIO_010054     http://semanticscience.org/resource/SIO_010054
# 9          Cell  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
#
#         property                                     property_uri  \
# 0    BFO_0000050       http://purl.obolibrary.org/obo/BFO_0000050
# 1    BFO_0000050       http://purl.obolibrary.org/obo/BFO_0000050
# 2           type  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3           type  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4  isDiscussedBy          http://purl.org/spar/cito/isDiscussedBy
# 5  isDiscussedBy          http://purl.org/spar/cito/isDiscussedBy
# 6     RO_0001000        http://purl.obolibrary.org/obo/RO_0001000
# 7     RO_0001000        http://purl.obolibrary.org/obo/RO_0001000
# 8      prefLabel    http://www.w3.org/2004/02/skos/core#prefLabel
# 9      prefLabel    http://www.w3.org/2004/02/skos/core#prefLabel
#
#   object_class                                     object_uri
# 0      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 1      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 2     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 3     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 4     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 5     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 6     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 7     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 8      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 9      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# Top 10 Classes by Property Count:
#   Cell: 8 properties
#   SIO_010054: 8 properties

# %% [markdown]
# ## Step 6: Domain-Specific Analysis
#
# #TODO: Add PubChem Cell-specific analysis

# %%
# TODO: Implement pubchem_cell-specific analysis
print("TODO: Add pubchem_cell analysis")
# Out:
# TODO: Add pubchem_cell analysis

# %% [markdown]
# ## Step 7: Export Results

# %%
try:
    if 'parser' in locals():
        # Export as JSON
        schema_json = parser.to_json(filter_void_nodes=True)
        
        import json
        with open(f"{dataset_name}_schema.json", "w") as f:
            json.dump(schema_json, f, indent=2)
        
        # Export as CSV
        schema_df.to_csv(f"{dataset_name}_schema.csv", index=False)
        
        print(f"Results exported:")
        print(f"  - {dataset_name}_void.ttl")
        print(f"  - {dataset_name}_schema.json")
        print(f"  - {dataset_name}_schema.csv")
        
except Exception as e:
    print(f"Export failed: {e}")
# Out:
# Results exported:
#   - pubchem_cell_void.ttl
#   - pubchem_cell_schema.json
#   - pubchem_cell_schema.csv

# %% [markdown]
# ## JSON-LD Export
#
# Export the VoID description and schema as JSON-LD with automatic prefix extraction.

# %%
# Export PubChem Cell data as JSON-LD (automatic prefix extraction)
print("Exporting PubChem Cell VoID and Schema as JSON-LD...")

# Export complete VoID with automatic context
void_jsonld = solver.export_void_jsonld(
    output_file="pubchem_cell_void.jsonld",
    indent=2
)

# Export schema only with automatic context
schema_jsonld = solver.export_schema_jsonld(
    output_file="pubchem_cell_schema.jsonld",
    indent=2,
    filter_void_nodes=True
)

print(f"Exported files:")
print(f"  - pubchem_cell_void.jsonld ({len(void_jsonld)} chars)")
print(f"  - pubchem_cell_schema.jsonld ({len(schema_jsonld)} chars)")

# Show automatically extracted prefixes
prefixes = solver._extract_prefixes_from_void()
print(f"\nAuto-extracted prefixes: {', '.join(sorted(prefixes.keys()))}")

print(f"\nSchema Preview:")
print(schema_jsonld[:300] + "..." if len(schema_jsonld) > 300 else schema_jsonld)
# Out:
# Exporting PubChem Cell VoID and Schema as JSON-LD...
# JSON-LD exported to: pubchem_cell_void.jsonld
# Schema JSON-LD exported to: pubchem_cell_schema.jsonld
# Exported files:
#   - pubchem_cell_void.jsonld (8850 chars)
#   - pubchem_cell_schema.jsonld (2867 chars)
#
# Auto-extracted prefixes: brick, csvw, dc, dcam, dcat, dcmitype, dcterms, doap, foaf, geo, ns1, odrl, org, owl, prof, prov, qb, rdf, rdfs, schema, sh, skos, sosa, ssn, time, vann, void, void-ext, wgs, xml, xsd
#
# Schema Preview:
# {
#   "@context": {
#     "@context": {
#       "brick": "https://brickschema.org/schema/Brick#",
#       "csvw": "http://www.w3.org/ns/csvw#",
#       "dc": "http://purl.org/dc/elements/1.1/",
#       "dcam": "http://purl.org/dc/dcam/",
#       "dcat": "http://www.w3.org/ns/dcat#",
#       "dcmitype": "http://purl...
