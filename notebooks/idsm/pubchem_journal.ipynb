# %% [markdown]
# # RDFSolve: PubChem Journal Analysis
#
# This notebook analyzes the PubChem Journal graph using RDFSolve:
# - **Graph URI**: http://rdf.ncbi.nlm.nih.gov/pubchem/journal
# - **SPARQL Endpoint**: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# - **Dataset**: PubChem Journal
#
# Explore the structure and schema of the PubChem Journal dataset.

# %%
import pandas as pd
from rdfsolve.rdfsolve import RDFSolver
from rdfsolve.void_parser import VoidParser
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Configure Dataset Parameters

# %%
# PubChem Journal configuration
endpoint_url = "https://idsm.elixir-czech.cz/sparql/endpoint/idsm"
graph_uri = "http://rdf.ncbi.nlm.nih.gov/pubchem/journal"
void_iri = "http://rdf.ncbi.nlm.nih.gov/pubchem/journal"
dataset_name = "pubchem_journal"
working_path = "."

print(f"Dataset: {dataset_name}")
print(f"Endpoint: {endpoint_url}")
print(f"Graph URI: {graph_uri}")
print(f"VoID IRI: {void_iri}")
# Out:
# Dataset: pubchem_journal
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/journal
# VoID IRI: http://rdf.ncbi.nlm.nih.gov/pubchem/journal

# %% [markdown]
# ## Step 2: Initialize RDFSolver

# %%
try:
    solver = RDFSolver(
        endpoint=endpoint_url,
        path=working_path,
        void_iri=void_iri,
        dataset_name=dataset_name
    )
    
    print("RDFSolver initialized successfully")
    print(f"Endpoint: {solver.endpoint}")
    print(f"Dataset: {solver.dataset_name}")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# RDFSolver initialized successfully
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Dataset: pubchem_journal

# %% [markdown]
# ## Step 3: Generate VoID Description

# %%
try:
    print("Generating VoID description...")
    
    void_graph = solver.void_generator(
        graph_uri=graph_uri,
        output_file=f"{dataset_name}_void.ttl",
        counts=True
    )
    
    print(f"VoID generation completed!")
    print(f"Graph contains {len(void_graph)} triples")
    print(f"Saved to: {dataset_name}_void.ttl")
    
except Exception as e:
    print(f"VoID generation failed: {e}")
# Out:
# Generating VoID description...
# Generating VoID from endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Using graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/journal
# Starting query: class_partitions
# Finished query: class_partitions (took 0.14s)
# Starting query: property_partitions
# Finished query: property_partitions (took 0.19s)
# Starting query: datatype_partitions
# Finished query: datatype_partitions (took 0.12s)
# VoID description saved to pubchem_journal_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 62 triples
# Saved to: pubchem_journal_void.ttl

# %% [markdown]
# ## Step 4: Extract Schema

# %%
try:
    print("Extracting schema from VoID...")
    parser = VoidParser(void_graph)
    
    schema_df = parser.to_schema(filter_void_nodes=True)
    
    print("Schema extraction completed")
    print(f"Total schema triples: {len(schema_df)}")
    print(f"Unique classes: {schema_df['subject_class'].nunique()}")
    print(f"Unique properties: {schema_df['property'].nunique()}")
    
except Exception as e:
    print(f"Schema extraction failed: {e}")
# Out:
# Extracting schema from VoID...
# Schema extraction completed
# Total schema triples: 14
# Unique classes: 1
# Unique properties: 7

# %% [markdown]
# ## Step 5: Schema Visualization

# %%
# Display schema sample
if 'schema_df' in locals():
    print("Schema Sample (first 10 rows):")
    display(schema_df.head(10))
    
    print("\nTop 10 Classes by Property Count:")
    class_counts = schema_df['subject_class'].value_counts().head(10)
    for cls, count in class_counts.items():
        print(f"  {cls}: {count} properties")
# Out:
# Schema Sample (first 10 rows):
#   subject_class                                        subject_uri  \
# 0       Journal  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 1       Journal                 http://purl.org/spar/fabio/Journal
# 2       Journal  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 3       Journal                 http://purl.org/spar/fabio/Journal
# 4       Journal                 http://purl.org/spar/fabio/Journal
# 5       Journal  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 6       Journal                 http://purl.org/spar/fabio/Journal
# 7       Journal  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 8       Journal  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 9       Journal                 http://purl.org/spar/fabio/Journal
#
#                                 property  \
# 0                                  title
# 1                                  title
# 2  hasNationalLibraryOfMedicineJournalId
# 3  hasNationalLibraryOfMedicineJournalId
# 4                                  eissn
# 5                                  eissn
# 6                                   issn
# 7                                   issn
# 8                             exactMatch
# 9                             exactMatch
#
#                                         property_uri object_class  \
# 0                     http://purl.org/dc/terms/title      Literal
# 1                     http://purl.org/dc/terms/title      Literal
# 2  http://purl.org/spar/fabio/hasNationalLibraryO...      Literal
# 3  http://purl.org/spar/fabio/hasNationalLibraryO...      Literal
# 4  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 5  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 6  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 7  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 8     http://www.w3.org/2004/02/skos/core#exactMatch     Resource
# 9     http://www.w3.org/2004/02/skos/core#exactMatch     Resource
#
#                                       object_uri
# 0   http://www.w3.org/2000/01/rdf-schema#Literal
# 1   http://www.w3.org/2000/01/rdf-schema#Literal
# 2   http://www.w3.org/2000/01/rdf-schema#Literal
# 3   http://www.w3.org/2000/01/rdf-schema#Literal
# 4   http://www.w3.org/2000/01/rdf-schema#Literal
# 5   http://www.w3.org/2000/01/rdf-schema#Literal
# 6   http://www.w3.org/2000/01/rdf-schema#Literal
# 7   http://www.w3.org/2000/01/rdf-schema#Literal
# 8  http://www.w3.org/2000/01/rdf-schema#Resource
# 9  http://www.w3.org/2000/01/rdf-schema#Resource
# Top 10 Classes by Property Count:
#   Journal: 14 properties

# %% [markdown]
# ## Step 6: Domain-Specific Analysis
#
# #TODO: Add PubChem Journal-specific analysis

# %%
# TODO: Implement pubchem_journal-specific analysis
print("TODO: Add pubchem_journal analysis")
# Out:
# TODO: Add pubchem_journal analysis

# %% [markdown]
# ## Step 7: Export Results

# %%
try:
    if 'parser' in locals():
        # Export as JSON
        schema_json = parser.to_json(filter_void_nodes=True)
        
        import json
        with open(f"{dataset_name}_schema.json", "w") as f:
            json.dump(schema_json, f, indent=2)
        
        # Export as CSV
        schema_df.to_csv(f"{dataset_name}_schema.csv", index=False)
        
        print(f"Results exported:")
        print(f"  - {dataset_name}_void.ttl")
        print(f"  - {dataset_name}_schema.json")
        print(f"  - {dataset_name}_schema.csv")
        
except Exception as e:
    print(f"Export failed: {e}")
# Out:
# Results exported:
#   - pubchem_journal_void.ttl
#   - pubchem_journal_schema.json
#   - pubchem_journal_schema.csv
