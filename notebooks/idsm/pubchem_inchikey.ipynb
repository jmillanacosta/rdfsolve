# %% [markdown]
# # RDFSolve: PubChem InChI Key Analysis
#
# This notebook analyzes the PubChem InChI Key graph using RDFSolve:
# - **Graph URI**: http://rdf.ncbi.nlm.nih.gov/pubchem/inchikey
# - **SPARQL Endpoint**: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# - **Dataset**: PubChem InChI Key
#
# Explore the structure and schema of the PubChem InChI Key dataset.

# %%
import pandas as pd
from rdfsolve.rdfsolve import RDFSolver
from rdfsolve.void_parser import VoidParser
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Configure Dataset Parameters

# %%
# PubChem InChI Key configuration
endpoint_url = "https://idsm.elixir-czech.cz/sparql/endpoint/idsm"
graph_uri = "http://rdf.ncbi.nlm.nih.gov/pubchem/inchikey"
void_iri = "http://rdf.ncbi.nlm.nih.gov/pubchem/inchikey"
dataset_name = "pubchem_inchikey"
working_path = "."

print(f"Dataset: {dataset_name}")
print(f"Endpoint: {endpoint_url}")
print(f"Graph URI: {graph_uri}")
print(f"VoID IRI: {void_iri}")
# Out:
# Dataset: pubchem_inchikey
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/inchikey
# VoID IRI: http://rdf.ncbi.nlm.nih.gov/pubchem/inchikey

# %% [markdown]
# ## Step 2: Initialize RDFSolver

# %%
try:
    solver = RDFSolver(
        endpoint=endpoint_url,
        path=working_path,
        void_iri=void_iri,
        dataset_name=dataset_name
    )
    
    print("RDFSolver initialized successfully")
    print(f"Endpoint: {solver.endpoint}")
    print(f"Dataset: {solver.dataset_name}")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# RDFSolver initialized successfully
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Dataset: pubchem_inchikey

# %% [markdown]
# ## Step 3: Generate VoID Description

# %%
try:
    print("Generating VoID description...")
    
    void_graph = solver.void_generator(
        graph_uri=graph_uri,
        output_file=f"{dataset_name}_void.ttl",
        counts=True
    )
    
    print(f"VoID generation completed!")
    print(f"Graph contains {len(void_graph)} triples")
    print(f"Saved to: {dataset_name}_void.ttl")
    
except Exception as e:
    print(f"VoID generation failed: {e}")
# Out:
# Generating VoID description...
# Generating VoID from endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Using graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/inchikey
# Starting query: class_partitions
# Finished query: class_partitions (took 14.56s)
# Starting query: property_partitions
# Finished query: property_partitions (took 63.78s)
# Starting query: datatype_partitions
# Finished query: datatype_partitions (took 13.51s)
# VoID description saved to pubchem_inchikey_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 56 triples
# Saved to: pubchem_inchikey_void.ttl

# %% [markdown]
# ## Step 4: Extract Schema

# %%
try:
    print("Extracting schema from VoID...")
    parser = VoidParser(void_graph)
    
    schema_df = parser.to_schema(filter_void_nodes=True)
    
    print("Schema extraction completed")
    print(f"Total schema triples: {len(schema_df)}")
    print(f"Unique classes: {schema_df['subject_class'].nunique()}")
    print(f"Unique properties: {schema_df['property'].nunique()}")
    
except Exception as e:
    print(f"Schema extraction failed: {e}")
# Out:
# Extracting schema from VoID...
# Schema extraction completed
# Total schema triples: 12
# Unique classes: 2
# Unique properties: 6

# %% [markdown]
# ## Step 5: Schema Visualization

# %%
# Display schema sample
if 'schema_df' in locals():
    print("Schema Sample (first 10 rows):")
    display(schema_df.head(10))
    
    print("\nTop 10 Classes by Property Count:")
    class_counts = schema_df['subject_class'].value_counts().head(10)
    for cls, count in class_counts.items():
        print(f"  {cls}: {count} properties")
# Out:
# Schema Sample (first 10 rows):
#     subject_class                                        subject_uri  \
# 0  CHEMINF_000399  http://semanticscience.org/resource/CHEMINF_00...
# 1        InChIKey  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 2  CHEMINF_000399  http://semanticscience.org/resource/CHEMINF_00...
# 3        InChIKey  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 4  CHEMINF_000399  http://semanticscience.org/resource/CHEMINF_00...
# 5        InChIKey  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 6  CHEMINF_000399  http://semanticscience.org/resource/CHEMINF_00...
# 7        InChIKey  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 8  CHEMINF_000399  http://semanticscience.org/resource/CHEMINF_00...
# 9        InChIKey  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
#
#           property                                       property_uri  \
# 0        has-value      http://semanticscience.org/resource/has-value
# 1        has-value      http://semanticscience.org/resource/has-value
# 2       SIO_000300     http://semanticscience.org/resource/SIO_000300
# 3       SIO_000300     http://semanticscience.org/resource/SIO_000300
# 4  is-attribute-of  http://semanticscience.org/resource/is-attribu...
# 5  is-attribute-of  http://semanticscience.org/resource/is-attribu...
# 6          subject                   http://purl.org/dc/terms/subject
# 7          subject                   http://purl.org/dc/terms/subject
# 8             type    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 9             type    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#   object_class                                     object_uri
# 0      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 1      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 2      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 3      Literal   http://www.w3.org/2000/01/rdf-schema#Literal
# 4     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 5     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 6     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 7     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 8     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# 9     Resource  http://www.w3.org/2000/01/rdf-schema#Resource
# Top 10 Classes by Property Count:
#   CHEMINF_000399: 6 properties
#   InChIKey: 6 properties

# %% [markdown]
# ## Step 6: Domain-Specific Analysis
#
# #TODO: Add PubChem InChI Key-specific analysis

# %%
# TODO: Implement pubchem_inchikey-specific analysis
print("TODO: Add pubchem_inchikey analysis")
# Out:
# TODO: Add pubchem_inchikey analysis

# %% [markdown]
# ## Step 7: Export Results

# %%
try:
    if 'parser' in locals():
        # Export as JSON
        schema_json = parser.to_json(filter_void_nodes=True)
        
        import json
        with open(f"{dataset_name}_schema.json", "w") as f:
            json.dump(schema_json, f, indent=2)
        
        # Export as CSV
        schema_df.to_csv(f"{dataset_name}_schema.csv", index=False)
        
        print(f"Results exported:")
        print(f"  - {dataset_name}_void.ttl")
        print(f"  - {dataset_name}_schema.json")
        print(f"  - {dataset_name}_schema.csv")
        
except Exception as e:
    print(f"Export failed: {e}")
# Out:
# Results exported:
#   - pubchem_inchikey_void.ttl
#   - pubchem_inchikey_schema.json
#   - pubchem_inchikey_schema.csv
