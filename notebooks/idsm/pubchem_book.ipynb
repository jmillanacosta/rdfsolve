# %% [markdown]
# # RDFSolve: PubChem Book Analysis
#
# This notebook analyzes the PubChem Book graph using RDFSolve:
# - **Graph URI**: http://rdf.ncbi.nlm.nih.gov/pubchem/book
# - **SPARQL Endpoint**: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# - **Dataset**: PubChem Book
#
# Explore the structure and schema of the PubChem Book dataset.

# %%
import pandas as pd
from rdfsolve.rdfsolve import RDFSolver
from rdfsolve.void_parser import VoidParser
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Configure Dataset Parameters

# %%
# PubChem Book configuration
endpoint_url = "https://idsm.elixir-czech.cz/sparql/endpoint/idsm"
graph_uri = "http://rdf.ncbi.nlm.nih.gov/pubchem/book"
void_iri = "http://rdf.ncbi.nlm.nih.gov/pubchem/book"
dataset_name = "pubchem_book"
working_path = "."

print(f"Dataset: {dataset_name}")
print(f"Endpoint: {endpoint_url}")
print(f"Graph URI: {graph_uri}")
print(f"VoID IRI: {void_iri}")
# Out:
# Dataset: pubchem_book
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/book
# VoID IRI: http://rdf.ncbi.nlm.nih.gov/pubchem/book

# %% [markdown]
# ## Step 2: Initialize RDFSolver

# %%
try:
    solver = RDFSolver(
        endpoint=endpoint_url,
        path=working_path,
        void_iri=void_iri,
        dataset_name=dataset_name
    )
    
    print("RDFSolver initialized successfully")
    print(f"Endpoint: {solver.endpoint}")
    print(f"Dataset: {solver.dataset_name}")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# RDFSolver initialized successfully
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Dataset: pubchem_book

# %% [markdown]
# ## Step 3: Generate VoID Description

# %%
try:
    print("Generating VoID description...")
    
    void_graph = solver.void_generator(
        graph_uri=graph_uri,
        output_file=f"{dataset_name}_void.ttl",
        counts=True
    )
    
    print(f"VoID generation completed!")
    print(f"Graph contains {len(void_graph)} triples")
    print(f"Saved to: {dataset_name}_void.ttl")
    
except Exception as e:
    print(f"VoID generation failed: {e}")
# Out:
# Generating VoID description...
# Generating VoID from endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Using graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/book
# Starting query: class_partitions
# Finished query: class_partitions (took 0.18s)
# Finished query: class_partitions (took 0.18s)
# Starting query: property_partitions
# Starting query: property_partitions
# Finished query: property_partitions (took 0.16s)
# Starting query: datatype_partitions
# Finished query: datatype_partitions (took 0.10s)
# VoID description saved to pubchem_book_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 78 triples
# Saved to: pubchem_book_void.ttl
# Finished query: datatype_partitions (took 0.10s)
# VoID description saved to pubchem_book_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 78 triples
# Saved to: pubchem_book_void.ttl

# %% [markdown]
# ## Step 4: Extract Schema

# %%
try:
    print("Extracting schema from VoID...")
    parser = VoidParser(void_graph)
    
    schema_df = parser.to_schema(filter_void_nodes=True)
    
    print("Schema extraction completed")
    print(f"Total schema triples: {len(schema_df)}")
    print(f"Unique classes: {schema_df['subject_class'].nunique()}")
    print(f"Unique properties: {schema_df['property'].nunique()}")
    
except Exception as e:
    print(f"Schema extraction failed: {e}")
# Out:
# Extracting schema from VoID...
# Schema extraction completed
# Total schema triples: 18
# Unique classes: 1
# Unique properties: 9

# %% [markdown]
# ## Step 5: Schema Visualization

# %%
# Display schema sample
if 'schema_df' in locals():
    print("Schema Sample (first 10 rows):")
    display(schema_df.head(10))
    
    print("\nTop 10 Classes by Property Count:")
    class_counts = schema_df['subject_class'].value_counts().head(10)
    for cls, count in class_counts.items():
        print(f"  {cls}: {count} properties")
# Out:
# Schema Sample (first 10 rows):
#   subject_class                                        subject_uri  property  \
# 0          Book  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...      date
# 1          Book                    http://purl.org/spar/fabio/Book      date
# 2          Book  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...   creator
# 3          Book                    http://purl.org/spar/fabio/Book   creator
# 4          Book                    http://purl.org/spar/fabio/Book      isbn
# 5          Book  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...      isbn
# 6          Book  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...      type
# 7          Book                    http://purl.org/spar/fabio/Book      type
# 8          Book  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...  subtitle
# 9          Book                    http://purl.org/spar/fabio/Book  subtitle
#
#                                         property_uri object_class  \
# 0                      http://purl.org/dc/terms/date      Literal
# 1                      http://purl.org/dc/terms/date      Literal
# 2                   http://purl.org/dc/terms/creator     Resource
# 3                   http://purl.org/dc/terms/creator     Resource
# 4  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 5  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 6    http://www.w3.org/1999/02/22-rdf-syntax-ns#type     Resource
# 7    http://www.w3.org/1999/02/22-rdf-syntax-ns#type     Resource
# 8  http://prismstandard.org/namespaces/basic/3.0/...      Literal
# 9  http://prismstandard.org/namespaces/basic/3.0/...      Literal
#
#                                       object_uri
# 0   http://www.w3.org/2000/01/rdf-schema#Literal
# 1   http://www.w3.org/2000/01/rdf-schema#Literal
# 2  http://www.w3.org/2000/01/rdf-schema#Resource
# 3  http://www.w3.org/2000/01/rdf-schema#Resource
# 4   http://www.w3.org/2000/01/rdf-schema#Literal
# 5   http://www.w3.org/2000/01/rdf-schema#Literal
# 6  http://www.w3.org/2000/01/rdf-schema#Resource
# 7  http://www.w3.org/2000/01/rdf-schema#Resource
# 8   http://www.w3.org/2000/01/rdf-schema#Literal
# 9   http://www.w3.org/2000/01/rdf-schema#Literal
# Top 10 Classes by Property Count:
#   Book: 18 properties

# %% [markdown]
# ## Step 6: Domain-Specific Analysis
#
# #TODO: Add PubChem Book-specific analysis

# %%
# TODO: Implement pubchem_book-specific analysis
print("TODO: Add pubchem_book analysis")
# Out:
# TODO: Add pubchem_book analysis

# %% [markdown]
# ## Step 7: Export Results

# %%
try:
    if 'parser' in locals():
        # Export as JSON
        schema_json = parser.to_json(filter_void_nodes=True)
        
        import json
        with open(f"{dataset_name}_schema.json", "w") as f:
            json.dump(schema_json, f, indent=2)
        
        # Export as CSV
        schema_df.to_csv(f"{dataset_name}_schema.csv", index=False)
        
        print(f"Results exported:")
        print(f"  - {dataset_name}_void.ttl")
        print(f"  - {dataset_name}_schema.json")
        print(f"  - {dataset_name}_schema.csv")
        
except Exception as e:
    print(f"Export failed: {e}")
# Out:
# Results exported:
#   - pubchem_book_void.ttl
#   - pubchem_book_schema.json
#   - pubchem_book_schema.csv

# %% [markdown]
# ## JSON-LD Export
#
# Export the VoID description and schema as JSON-LD with PubChem-specific context.

# %%
# Export PubChem Book data as JSON-LD
print("Exporting PubChem Book VoID and Schema as JSON-LD...")

# PubChem-specific JSON-LD context
pubchem_context = {
    "@context": {
        "void": "http://rdfs.org/ns/void#",
        "void-ext": "http://ldf.fi/void-ext#",
        "pubchem": "http://rdf.ncbi.nlm.nih.gov/pubchem/",
        "sio": "http://semanticscience.org/resource/",
        "fabio": "http://purl.org/spar/fabio/",
        "dc": "http://purl.org/dc/elements/1.1/",
        "foaf": "http://xmlns.com/foaf/0.1/",
        "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
        "rdfs": "http://www.w3.org/2000/01/rdf-schema#"
    }
}

# Export complete VoID
void_jsonld = solver.export_void_jsonld(
    output_file="pubchem_book_void.jsonld",
    context=pubchem_context,
    indent=2
)

# Export schema only
schema_jsonld = solver.export_schema_jsonld(
    output_file="pubchem_book_schema.jsonld",
    context=pubchem_context,
    indent=2,
    filter_void_nodes=True
)

print(f"Exported files:")
print(f"  - pubchem_book_void.jsonld ({len(void_jsonld)} chars)")
print(f"  - pubchem_book_schema.jsonld ({len(schema_jsonld)} chars)")

# Show schema structure
import json
try:
    schema_data = json.loads(schema_jsonld)
    if "@graph" in schema_data:
        print(f"\nSchema contains {len(schema_data['@graph'])} RDF statements")
    else:
        print(f"\nSchema structure: {list(schema_data.keys())}")
except:
    print("\nSchema Preview:")
    print(schema_jsonld[:300] + "..." if len(schema_jsonld) > 300 else schema_jsonld)
# Out:
# Exporting PubChem Book VoID and Schema as JSON-LD...
# JSON-LD exported to: pubchem_book_void.jsonld
# Schema JSON-LD exported to: pubchem_book_schema.jsonld
# Exported files:
#   - pubchem_book_void.jsonld (8535 chars)
#   - pubchem_book_schema.jsonld (2175 chars)
#
# Schema contains 2 RDF statements
