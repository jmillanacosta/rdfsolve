# %% [markdown]
# # RDFSolve: PubChem Measure Group Analysis
#
# This notebook analyzes the PubChem Measure Group graph using RDFSolve:
# - **Graph URI**: http://rdf.ncbi.nlm.nih.gov/pubchem/measuregroup
# - **SPARQL Endpoint**: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# - **Dataset**: PubChem Measure Group
#
# Explore the structure and schema of the PubChem Measure Group dataset.

# %%
import pandas as pd
from rdfsolve.rdfsolve import RDFSolver
from rdfsolve.void_parser import VoidParser
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1: Configure Dataset Parameters

# %%
# PubChem Measure Group configuration
endpoint_url = "https://idsm.elixir-czech.cz/sparql/endpoint/idsm"
graph_uri = "http://rdf.ncbi.nlm.nih.gov/pubchem/measuregroup"
void_iri = "http://rdf.ncbi.nlm.nih.gov/pubchem/measuregroup"
dataset_name = "pubchem_measuregroup"
working_path = "."

print(f"Dataset: {dataset_name}")
print(f"Endpoint: {endpoint_url}")
print(f"Graph URI: {graph_uri}")
print(f"VoID IRI: {void_iri}")
# Out:
# Dataset: pubchem_measuregroup
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/measuregroup
# VoID IRI: http://rdf.ncbi.nlm.nih.gov/pubchem/measuregroup

# %% [markdown]
# ## Step 2: Initialize RDFSolver

# %%
try:
    solver = RDFSolver(
        endpoint=endpoint_url,
        path=working_path,
        void_iri=void_iri,
        dataset_name=dataset_name
    )
    
    print("RDFSolver initialized successfully")
    print(f"Endpoint: {solver.endpoint}")
    print(f"Dataset: {solver.dataset_name}")
    
except Exception as e:
    print(f"Error: {e}")
# Out:
# RDFSolver initialized successfully
# Endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Dataset: pubchem_measuregroup

# %% [markdown]
# ## Step 3: Generate VoID Description

# %%
try:
    print("Generating VoID description...")
    
    void_graph = solver.void_generator(
        graph_uri=graph_uri,
        output_file=f"{dataset_name}_void.ttl",
        counts=True
    )
    
    print(f"VoID generation completed!")
    print(f"Graph contains {len(void_graph)} triples")
    print(f"Saved to: {dataset_name}_void.ttl")
    
except Exception as e:
    print(f"VoID generation failed: {e}")
# Out:
# Generating VoID description...
# Generating VoID from endpoint: https://idsm.elixir-czech.cz/sparql/endpoint/idsm
# Using graph URI: http://rdf.ncbi.nlm.nih.gov/pubchem/measuregroup
# Starting query: class_partitions
# Finished query: class_partitions (took 0.49s)
# Starting query: property_partitions
# Finished query: property_partitions (took 37.06s)
# Starting query: datatype_partitions
# Finished query: datatype_partitions (took 0.36s)
# VoID description saved to pubchem_measuregroup_void.ttl
# VoID generation completed successfully
# VoID generation completed!
# Graph contains 46 triples
# Saved to: pubchem_measuregroup_void.ttl

# %% [markdown]
# ## Step 4: Extract Schema

# %%
try:
    print("Extracting schema from VoID...")
    parser = VoidParser(void_graph)
    
    schema_df = parser.to_schema(filter_void_nodes=True)
    
    print("Schema extraction completed")
    print(f"Total schema triples: {len(schema_df)}")
    print(f"Unique classes: {schema_df['subject_class'].nunique()}")
    print(f"Unique properties: {schema_df['property'].nunique()}")
    
except Exception as e:
    print(f"Schema extraction failed: {e}")
# Out:
# Extracting schema from VoID...
# Schema extraction completed
# Total schema triples: 10
# Unique classes: 2
# Unique properties: 5

# %% [markdown]
# ## Step 5: Schema Visualization

# %%
# Display schema sample
if 'schema_df' in locals():
    print("Schema Sample (first 10 rows):")
    display(schema_df.head(10))
    
    print("\nTop 10 Classes by Property Count:")
    class_counts = schema_df['subject_class'].value_counts().head(10)
    for cls, count in class_counts.items():
        print(f"  {cls}: {count} properties")
# Out:
# Schema Sample (first 10 rows):
#   subject_class                                        subject_uri  \
# 0   BAO_0000040    http://www.bioassayontology.org/bao#BAO_0000040
# 1  MeasureGroup  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 2  MeasureGroup  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 3   BAO_0000040    http://www.bioassayontology.org/bao#BAO_0000040
# 4   BAO_0000040    http://www.bioassayontology.org/bao#BAO_0000040
# 5  MeasureGroup  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 6  MeasureGroup  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
# 7   BAO_0000040    http://www.bioassayontology.org/bao#BAO_0000040
# 8   BAO_0000040    http://www.bioassayontology.org/bao#BAO_0000040
# 9  MeasureGroup  http://rdf.ncbi.nlm.nih.gov/pubchem/vocabulary...
#
#       property                                     property_uri object_class  \
# 0  OBI_0000299       http://purl.obolibrary.org/obo/OBI_0000299     Resource
# 1  OBI_0000299       http://purl.obolibrary.org/obo/OBI_0000299     Resource
# 2       source                  http://purl.org/dc/terms/source     Resource
# 3       source                  http://purl.org/dc/terms/source     Resource
# 4         type  http://www.w3.org/1999/02/22-rdf-syntax-ns#type     Resource
# 5         type  http://www.w3.org/1999/02/22-rdf-syntax-ns#type     Resource
# 6        title                   http://purl.org/dc/terms/title      Literal
# 7        title                   http://purl.org/dc/terms/title      Literal
# 8   RO_0000057        http://purl.obolibrary.org/obo/RO_0000057     Resource
# 9   RO_0000057        http://purl.obolibrary.org/obo/RO_0000057     Resource
#
#                                       object_uri
# 0  http://www.w3.org/2000/01/rdf-schema#Resource
# 1  http://www.w3.org/2000/01/rdf-schema#Resource
# 2  http://www.w3.org/2000/01/rdf-schema#Resource
# 3  http://www.w3.org/2000/01/rdf-schema#Resource
# 4  http://www.w3.org/2000/01/rdf-schema#Resource
# 5  http://www.w3.org/2000/01/rdf-schema#Resource
# 6   http://www.w3.org/2000/01/rdf-schema#Literal
# 7   http://www.w3.org/2000/01/rdf-schema#Literal
# 8  http://www.w3.org/2000/01/rdf-schema#Resource
# 9  http://www.w3.org/2000/01/rdf-schema#Resource
# Top 10 Classes by Property Count:
#   BAO_0000040: 5 properties
#   MeasureGroup: 5 properties

# %% [markdown]
# ## Step 6: Domain-Specific Analysis
#
# #TODO: Add PubChem Measure Group-specific analysis

# %%
# TODO: Implement measure group-specific analysis
print("TODO: Add measure group analysis")
# Out:
# TODO: Add measure group analysis

# %% [markdown]
# ## Step 7: Export Results

# %%
try:
    if 'parser' in locals():
        # Export as JSON
        schema_json = parser.to_json(filter_void_nodes=True)
        
        import json
        with open(f"{dataset_name}_schema.json", "w") as f:
            json.dump(schema_json, f, indent=2)
        
        # Export as CSV
        schema_df.to_csv(f"{dataset_name}_schema.csv", index=False)
        
        print(f"Results exported:")
        print(f"  - {dataset_name}_void.ttl")
        print(f"  - {dataset_name}_schema.json")
        print(f"  - {dataset_name}_schema.csv")
        
except Exception as e:
    print(f"Export failed: {e}")
# Out:
# Results exported:
#   - pubchem_measuregroup_void.ttl
#   - pubchem_measuregroup_schema.json
#   - pubchem_measuregroup_schema.csv
