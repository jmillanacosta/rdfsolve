# %% [markdown]
# <style>
#
# /* Main content area */
# .jp-RenderedHTMLCommon {
#     font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', 'Noto Sans', Helvetica, Arial, sans-serif;
#     line-height: 1.6;
#     color: #24292f;
# }
#
# /* Headers */
# .jp-RenderedHTMLCommon h1 {
#     border-bottom: 1px solid #d1d9e0;
#     padding-bottom: 8px;
#     margin-bottom: 16px;
#     font-weight: 600;
#     color: #1f2328;
# }
#
# .jp-RenderedHTMLCommon h2 {
#     border-bottom: 1px solid #d8dee4;
#     padding-bottom: 6px;
#     margin-top: 24px;
#     margin-bottom: 16px;
#     font-weight: 600;
#     color: #1f2328;
# }
#
# .jp-RenderedHTMLCommon h3 {
#     margin-top: 20px;
#     margin-bottom: 12px;
#     font-weight: 600;
#     color: #1f2328;
# }
#
# /* Code blocks and inline code */
# .jp-RenderedHTMLCommon code {
#     background-color: #f6f8fa;
#     border-radius: 6px;
#     padding: 2px 6px;
#     font-family: 'SFMono-Regular', Consolas, 'Liberation Mono', Menlo, monospace;
#     font-size: 85%;
#     color: #1f2328;
# }
#
# .jp-RenderedHTMLCommon pre {
#     background-color: #f6f8fa;
#     border-radius: 6px;
#     padding: 16px;
#     overflow: auto;
#     font-family: 'SFMono-Regular', Consolas, 'Liberation Mono', Menlo, monospace;
#     font-size: 85%;
#     line-height: 1.45;
# }
#
# /* Lists */
# .jp-RenderedHTMLCommon ul, .jp-RenderedHTMLCommon ol {
#     margin-bottom: 16px;
# }
#
# .jp-RenderedHTMLCommon li {
#     margin-bottom: 4px;
# }
#
# /* Links */
# .jp-RenderedHTMLCommon a {
#     color: #0969da;
#     text-decoration: none;
# }
#
# .jp-RenderedHTMLCommon a:hover {
#     text-decoration: underline;
# }
#
# /* Tables */
# .jp-RenderedHTMLCommon table {
#     border-collapse: collapse;
#     border-spacing: 0;
#     width: 100%;
#     margin-bottom: 16px;
# }
#
# .jp-RenderedHTMLCommon th,
# .jp-RenderedHTMLCommon td {
#     padding: 6px 13px;
#     border: 1px solid #d1d9e0;
#     text-align: left;
# }
#
# .jp-RenderedHTMLCommon th {
#     background-color: #f6f8fa;
#     font-weight: 600;
# }
#
# .jp-RenderedHTMLCommon tr:nth-child(2n) {
#     background-color: #f6f8fa;
# }
#
# /* Blockquotes */
# .jp-RenderedHTMLCommon blockquote {
#     border-left: 4px solid #d1d9e0;
#     padding-left: 16px;
#     margin-left: 0;
#     color: #656d76;
# }
#
# /* Emphasized text */
# .jp-RenderedHTMLCommon strong {
#     font-weight: 600;
# }
#
# .jp-RenderedHTMLCommon em {
#     font-style: italic;
# }
#
# /* Output areas - DataFrames and plots */
# .jp-OutputArea-output table {
#     font-size: 12px;
#     border-collapse: collapse;
#     margin: 8px 0;
# }
#
# .jp-OutputArea-output th {
#     background-color: #f1f3f4;
#     padding: 8px;
#     text-align: left;
#     font-weight: 500;
#     border: 1px solid #dadce0;
# }
#
# .jp-OutputArea-output td {
#     padding: 6px 8px;
#     border: 1px solid #dadce0;
#     max-width: 200px;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     white-space: nowrap;
# }
#
# /* Status indicators */
# .status-success {
#     color: #1a7f37;
#     font-weight: 500;
# }
#
# .status-warning {
#     color: #9a6700;
#     font-weight: 500;
# }
#
# .status-error {
#     color: #d1242f;
#     font-weight: 500;
# }
#
# /* Schema pattern labels */
# .schema-pattern {
#     font-family: 'SFMono-Regular', Consolas, monospace;
#     background-color: #f6f8fa;
#     padding: 2px 4px;
#     border-radius: 3px;
#     font-size: 90%;
# }
#
# /* Export links styling */
# .exports-list a {
#     display: inline-block;
#     margin-right: 12px;
#     padding: 4px 8px;
#     background-color: #f3f4f6;
#     border-radius: 6px;
#     border: 1px solid #d1d9e0;
#     text-decoration: none;
#     font-size: 14px;
#     font-weight: 500;
# }
#
# .exports-list a:hover {
#     background-color: #e1e4e8;
#     text-decoration: none;
# }
#
# /* Plotly chart container */
# .plotly-graph-div {
#     border: 1px solid #e1e4e8;
#     border-radius: 6px;
#     margin: 16px 0;
# }
#
# /* Cache status indicators */
# .cache-info {
#     font-family: 'SFMono-Regular', Consolas, monospace;
#     font-size: 12px;
#     color: #656d76;
#     background-color: #f6f8fa;
#     padding: 8px;
#     border-radius: 6px;
#     border-left: 3px solid #0969da;
# }
#
# /* Notebook section dividers */
# .section-divider {
#     height: 1px;
#     background: linear-gradient(to right, transparent, #d1d9e0, transparent);
#     margin: 32px 0;
# }
#
# /* Print styles */
# @media print {
#     .jp-RenderedHTMLCommon {
#         color: #000;
#     }
#
#     .jp-RenderedHTMLCommon a {
#         color: #000;
#         text-decoration: underline;
#     }
# }
# </style>

# %% [markdown]
# # aopwikirdf Schema Extraction
#
# This notebook demonstrates RDF schema extraction from the aopwikirdf SPARQL endpoint. It discovers VoID (Vocabulary of Interlinked Datasets) descriptions and generates  JSON-LD as the source for all downstream outputs including frequency analysis and LinkML schemas.

# %% [markdown]
# ## Exports
#
# - [JSON-LD Schema](https://github.com/jmillanacosta/rdfsolve/blob/main/data/schema_extraction/aopwikirdf_schema/aopwikirdf_schema.jsonld) (primary output)
# - [N-Quads RDF](https://github.com/jmillanacosta/rdfsolve/blob/main/data/schema_extraction/aopwikirdf_schema/aopwikirdf_schema.nq)
# - [VoID Graph](https://github.com/jmillanacosta/rdfsolve/blob/main/data/schema_extraction/aopwikirdf_schema/aopwikirdf_generated_void.ttl) for the dataset in its original source
# - [Coverage report](https://github.com/jmillanacosta/rdfsolve/blob/main/data/schema_extraction/aopwikirdf_schema/aopwikirdf_pattern_coverage.csv)
# - [LinkML Schema](https://github.com/jmillanacosta/rdfsolve/blob/main/data/schema_extraction/aopwikirdf_schema/aopwikirdf_linkml_schema.yaml)
# - [Full parquet entity dataframe](https://github.com/jmillanacosta/rdfsolve/blob/main/data/schema_extraction/aopwikirdf_schema/aopwikirdfinstances.parquet)

# %%
# Dataset Configuration
import os

# Dataset parameters
endpoint_url = "https://aopwiki.rdf.bigcat-bioinformatics.org/sparql/"
dataset_name = "aopwikirdf"
void_iri = "http://aopwiki.org/"
graph_uri = "http://aopwiki.org/"

# Setup paths
working_path = os.path.abspath("")
exports_path = os.path.join(
    working_path, "..", "..", "docs", "data", "schema_extraction", dataset_name
)
os.makedirs(exports_path, exist_ok=True)

# %%
import logging
import sys

# Minimal notebook logger using existing dataset_name
logger = logging.getLogger(dataset_name or "notebook")
logger.setLevel(logging.DEBUG)  # Set to DEBUG to see SPARQL queries

# Also configure the rdfsolve.parser logger to see query details
parser_logger = logging.getLogger("rdfsolve.parser")
parser_logger.setLevel(logging.DEBUG)

# Avoid adding duplicate handlers if the cell is re-run
if not logger.handlers:
    fmt = logging.Formatter("%(asctime)s %(levelname)s %(name)s: %(message)s", "%Y-%m-%d %H:%M:%S")

    sh = logging.StreamHandler(sys.stdout)
    sh.setLevel(logging.DEBUG)  # Set to DEBUG to see all logs
    sh.setFormatter(fmt)
    logger.addHandler(sh)

    # Add the same handler to the parser logger
    parser_logger.addHandler(sh)

logger.info(f"Logging configured for {dataset_name}")
# Out:
# 2025-11-26 13:51:13 INFO aopwikirdf: Logging configured for aopwikirdf

# %%
# Import libraries
import json

# Configure Plotly for HTML output
import plotly.io as pio
import plotly.offline as pyo
from IPython.display import Markdown, display

from rdfsolve.parser import VoidParser

# Set renderer to 'notebook' for Jupyter, but ensure HTML export works
pio.renderers.default = "notebook+plotly_mimetype"

# Initialize offline mode for Plotly
pyo.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.2.0.min"</script>

# %%
# Pickle caching utilities
import os
import pickle


def save_cache(data, filename, cache_dir=None):
    """Save data to pickle cache."""
    if cache_dir is None:
        cache_dir = os.path.join(exports_path, "cache")
    os.makedirs(cache_dir, exist_ok=True)

    cache_path = os.path.join(cache_dir, f"{filename}.pkl")
    with open(cache_path, "wb") as f:
        pickle.dump(data, f)
    print(f"Cached data to: {cache_path}")
    return cache_path


def load_cache(filename, cache_dir=None):
    """Load data from pickle cache if it exists."""
    if cache_dir is None:
        cache_dir = os.path.join(exports_path, "cache")

    cache_path = os.path.join(cache_dir, f"{filename}.pkl")
    if os.path.exists(cache_path):
        with open(cache_path, "rb") as f:
            data = pickle.load(f)
        print(f"Loaded cached data from: {cache_path}")
        return data
    return None


def cache_exists(filename, cache_dir=None):
    """Check if cache file exists."""
    if cache_dir is None:
        cache_dir = os.path.join(exports_path, "cache")

    cache_path = os.path.join(cache_dir, f"{filename}.pkl")
    return os.path.exists(cache_path)

# %%
# Cache management utilities
def list_cache_files(cache_dir=None):
    """List all cache files."""
    if cache_dir is None:
        cache_dir = os.path.join(exports_path, "cache")

    if not os.path.exists(cache_dir):
        print("No cache directory found")
        return []

    cache_files = [f for f in os.listdir(cache_dir) if f.endswith(".pkl")]
    print(f"Cache directory: {cache_dir}")
    for f in cache_files:
        file_path = os.path.join(cache_dir, f)
        size_mb = os.path.getsize(file_path) / (1024 * 1024)
        print(f"  {f} ({size_mb:.2f} MB)")
    return cache_files


def clear_cache(filename=None, cache_dir=None):
    """Clear specific cache file or all cache."""
    if cache_dir is None:
        cache_dir = os.path.join(exports_path, "cache")

    if filename:
        cache_path = os.path.join(cache_dir, f"{filename}.pkl")
        if os.path.exists(cache_path):
            os.remove(cache_path)
            print(f"Removed cache: {filename}")
        else:
            print(f"Cache not found: {filename}")
    else:
        # Clear all cache files
        if os.path.exists(cache_dir):
            import shutil

            shutil.rmtree(cache_dir)
            print("Cleared all cache files")
        else:
            print("No cache directory to clear")


# Show current cache status
list_cache_files()
# Out:
# No cache directory found
# []

# %% [markdown]
# ### Cache Control
#
# Use these cells to manage cached data. When testing new code changes, you may want to clear relevant cache files to force re-computation.

# %%
# Clear specific cache files (uncomment lines as needed for testing)

# When testing new parser changes:
# clear_cache(f"{dataset_name}_voidparser")

# When testing JSON-LD generation (primary output):
# clear_cache(f"{dataset_name}_jsonld_schema")

# When testing frequency calculations:
# clear_cache(f"{dataset_name}_frequencies_basic")
# clear_cache(f"{dataset_name}_frequencies_with_instances")

# Clear everything:
# clear_cache()

print("Cleared parser and JSON-LD caches to test schema pattern fix")
print("Note: JSON-LD cache is now the primary cache - clear it when testing schema changes.")
# Out:
# Cleared parser and JSON-LD caches to test schema pattern fix
# Note: JSON-LD cache is now the primary cache - clear it when testing schema changes.

# %% [markdown]
# ## Discover or get VoID Schema

# %%
# Generate VoID schema with caching
cache_key = f"{dataset_name}_voidparser"

# Try to load from cache first
vp = load_cache(cache_key)

if vp is None:
    print("VoidParser not found in cache, generating...")
    vp = VoidParser.from_endpoint_with_discovery(
        endpoint_url=endpoint_url,
        dataset_name=dataset_name,
        exports_path=exports_path,
        # Arguments for the case when a suitable VoID is not found
        graph_uris=[graph_uri] if graph_uri else None,
        exclude_graph_patterns=[
            "openlinksw",
            "well-known",
            "void",
            "service",
        ],  # Filter out service description and administrative graphs
        counts=True,
        offset_limit_steps=300,  # pagination
    )
    # Cache the VoidParser for future use
    save_cache(vp, cache_key)
else:
    print("Loaded VoidParser from cache")
# Out:
# VoidParser not found in cache, generating...
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Starting endpoint discovery process...
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Endpoint: https://aopwiki.rdf.bigcat-bioinformatics.org/sparql/
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Dataset: aopwikirdf
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser:  Provided graph URIs: ['http://aopwiki.org/']
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Settings: prefer_existing=True, exclude_graphs=True
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Validating provided graph URIs...
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Endpoint: https://aopwiki.rdf.bigcat-bioinformatics.org/sparql/
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Dataset: aopwikirdf
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser:  Provided graph URIs: ['http://aopwiki.org/']
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Settings: prefer_existing=True, exclude_graphs=True
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Validating provided graph URIs...
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Step 1: Discovering existing VoID graphs...
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser:  Starting chunked VoID graph discovery for https://aopwiki.rdf.bigcat-bioinformatics.org/sparql/
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Starting VoID graph discovery with pagination...
# 2025-11-26 13:51:17 INFO rdfsolve.parser: Discovering VoID candidate graphs with chunked approach
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Executing chunked query: offset=0, limit=50
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Step 1: Discovering existing VoID graphs...
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser:  Starting chunked VoID graph discovery for https://aopwiki.rdf.bigcat-bioinformatics.org/sparql/
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Starting VoID graph discovery with pagination...
# 2025-11-26 13:51:17 INFO rdfsolve.parser: Discovering VoID candidate graphs with chunked approach
# 2025-11-26 13:51:17 DEBUG rdfsolve.parser: Executing chunked query: offset=0, limit=50
# 2025-11-26 13:51:18 INFO rdfsolve.parser: Candidate VoID graph at servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Fetched chunk: 1 results (total: 1)
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Partial chunk received, pagination complete
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Found 1 candidate VoID graphs
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Starting detailed VoID content analysis...
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Analyzing graph 1/1: servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Discovering partitions in servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Class partition query template:
#
#                     SELECT DISTINCT ?cp WHERE {
#                         GRAPH <servicedescription> {
#                             ?cp <http://rdfs.org/ns/void#class> ?class .
#                         }...
# 2025-11-26 13:51:18 WARNING rdfsolve.parser: Error analyzing VoID partitions in servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Full error details:
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Error type: ValueError
# 2025-11-26 13:51:18 INFO rdfsolve.parser: Candidate VoID graph at servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Fetched chunk: 1 results (total: 1)
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Partial chunk received, pagination complete
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Found 1 candidate VoID graphs
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Starting detailed VoID content analysis...
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Analyzing graph 1/1: servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Discovering partitions in servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Class partition query template:
#
#                     SELECT DISTINCT ?cp WHERE {
#                         GRAPH <servicedescription> {
#                             ?cp <http://rdfs.org/ns/void#class> ?class .
#                         }...
# 2025-11-26 13:51:18 WARNING rdfsolve.parser: Error analyzing VoID partitions in servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Full error details:
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Error type: ValueError
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Error message: unexpected '{' in field name
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Graph URI: servicedescription
# 2025-11-26 13:51:18 WARNING rdfsolve.parser: Possible SPARQL syntax issue with URI: servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: VoID discovery analysis complete
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:  Results summary:
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Total candidate graphs: 1
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Graphs with VoID data: 0
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Has VoID descriptions: False
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Error message: unexpected '{' in field name
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Graph URI: servicedescription
# 2025-11-26 13:51:18 WARNING rdfsolve.parser: Possible SPARQL syntax issue with URI: servicedescription
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: VoID discovery analysis complete
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:  Results summary:
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Total candidate graphs: 1
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Graphs with VoID data: 0
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser:    • Has VoID descriptions: False
# 2025-11-26 13:51:18 INFO rdfsolve.parser: No VoID data found in any candidate graphs
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Discovery result: found=False
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Found 0 graphs with VoID data
# 2025-11-26 13:51:18 INFO rdfsolve.parser: No suitable VoID found; generating from queries...
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Step 2: Generating new VoID from SPARQL queries...
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Generation settings: counts=True, offset_limit_steps=300
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Output path: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_generated_void.ttl
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Starting VoID generation process...
# 2025-11-26 13:51:18 INFO rdfsolve.parser: No VoID data found in any candidate graphs
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Discovery result: found=False
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Found 0 graphs with VoID data
# 2025-11-26 13:51:18 INFO rdfsolve.parser: No suitable VoID found; generating from queries...
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Step 2: Generating new VoID from SPARQL queries...
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Generation settings: counts=True, offset_limit_steps=300
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Output path: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_generated_void.ttl
# 2025-11-26 13:51:18 DEBUG rdfsolve.parser: Starting VoID generation process...
# 2025-11-26 13:51:19 INFO rdfsolve.parser: Successfully extracted 346 RDF triples
# 2025-11-26 13:51:19 INFO rdfsolve.parser: Successfully extracted 346 RDF triples
# 2025-11-26 13:51:19 INFO rdfsolve.parser: VoID description saved to /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_generated_void.ttl
# 2025-11-26 13:51:19 DEBUG rdfsolve.parser: VoID generation completed
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_voidparser.pkl
# 2025-11-26 13:51:19 INFO rdfsolve.parser: VoID description saved to /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_generated_void.ttl
# 2025-11-26 13:51:19 DEBUG rdfsolve.parser: VoID generation completed
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_voidparser.pkl

# %% [markdown]
# ## Schema Discovery and Exports Workflow
#
# ### Workflow Steps:
#
# 1. **VoID Discovery**: Extract schema patterns from SPARQL endpoint VoID descriptions
# 2. **JSON-LD Generation**: Convert to JSON-LD.
# 3. **Derived Outputs**: All other formats are generated from the JSON-LD structure:
#    - **Frequencies**: Schema pattern coverage analysis
#    - **LinkML**: LinkML YAML used elsewhere for other features.
#    - **CSV/JSON**: Tabular and structured data exports
#    - **RDF**: N-Quads serialization for triplestore import

# %%
# Primary JSON-LD schema export and basic summary
cache_key = f"{dataset_name}_jsonld_schema"
jsonld_schema = load_cache(cache_key)

if jsonld_schema is None:
    print("Generating standards-compliant JSON-LD schema...")
    jsonld_schema = vp.to_jsonld(filter_void_admin_nodes=True)
    save_cache(jsonld_schema, cache_key)
else:
    print("Loaded JSON-LD schema from cache")

# Save JSON-LD schema file
jsonld_file = os.path.join(exports_path, f"{dataset_name}_schema.jsonld")
with open(jsonld_file, "w", encoding="utf-8") as f:
    json.dump(jsonld_schema, f, indent=2, ensure_ascii=False)

print(f"JSON-LD Schema saved to: {jsonld_file}")

# Display combined JSON-LD structure info and schema summary
if "@graph" in jsonld_schema:
    print("\nSchema Summary:")
    print(f"   • Prefixes: {len(jsonld_schema['@context'])}")
    print(f"   • Resources: {len(jsonld_schema['@graph'])}")

    # Show dataset metadata
    dataset_info = jsonld_schema["@graph"][0] if jsonld_schema["@graph"] else {}
    if dataset_info.get("@type") == "void:Dataset":
        print(f"   • Dataset: {dataset_info.get('dcterms:title', 'Unknown')}")
        print(f"   • Classes: {dataset_info.get('void:classes', 0)}")
        print(f"   • Properties: {dataset_info.get('void:properties', 0)}")
        print(f"   • Triples: {dataset_info.get('void:triples', 0)}")

# Get schema DataFrame and show sample
schema_df = vp.to_schema(filter_void_admin_nodes=True)
print(f"\nSchema Patterns Preview ({len(schema_df)} total):")
display(schema_df.head())
# Out:
# Generating standards-compliant JSON-LD schema...
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_jsonld_schema.pkl
# JSON-LD Schema saved to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_schema.jsonld
#
# Schema Summary:
#    • Prefixes: 14
#    • Resources: 16
#
# Schema Patterns Preview (96 total):
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_jsonld_schema.pkl
# JSON-LD Schema saved to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_schema.jsonld
#
# Schema Summary:
#    • Prefixes: 14
#    • Resources: 16
#
# Schema Patterns Preview (96 total):
#                 subject_class  \
# 0   aopo:KeyEventRelationship
# 1               aopo:KeyEvent
# 2  aopo:AdverseOutcomePathway
# 3                 ncit:C54571
# 4  aopo:AdverseOutcomePathway
#
#                                          subject_uri     property  \
# 0  http://aopkb.org/aop_ontology#KeyEventRelation...    foaf:page
# 1             http://aopkb.org/aop_ontology#KeyEvent    foaf:page
# 2  http://aopkb.org/aop_ontology#AdverseOutcomePa...    foaf:page
# 3  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...    foaf:page
# 4  http://aopkb.org/aop_ontology#AdverseOutcomePa...  ncit:C54571
#
#                                         property_uri  \
# 0                     http://xmlns.com/foaf/0.1/page
# 1                     http://xmlns.com/foaf/0.1/page
# 2                     http://xmlns.com/foaf/0.1/page
# 3                     http://xmlns.com/foaf/0.1/page
# 4  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
#
#                  object_class  \
# 0   aopo:KeyEventRelationship
# 1               aopo:KeyEvent
# 2  aopo:AdverseOutcomePathway
# 3                 ncit:C54571
# 4                 ncit:C54571
#
#                                           object_uri
# 0  http://aopkb.org/aop_ontology#KeyEventRelation...
# 1             http://aopkb.org/aop_ontology#KeyEvent
# 2  http://aopkb.org/aop_ontology#AdverseOutcomePa...
# 3  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...
# 4  http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus...

# %% [markdown]
# ## Schema Pattern Coverage Analysis
# Calculate coverage ratios showing what percentage of entities use each relationship pattern.

# %%
# Schema pattern coverage analysis and export
cache_key = f"{dataset_name}_frequencies_basic"
cached_data = load_cache(cache_key)

if cached_data is None:
    print("Calculating schema pattern frequencies...")
    frequencies_df, _ = vp.count_schema_shape_frequencies(
        endpoint_url=endpoint_url,
        offset_limit_steps=300,
    )
    save_cache(frequencies_df, cache_key)
else:
    print("Loaded frequencies DataFrame from cache")
    frequencies_df = cached_data

# Export coverage analysis
frequencies_output_path = os.path.join(exports_path, f"{dataset_name}_pattern_coverage.csv")
exported_df = vp.export_schema_shape_frequencies(
    frequencies_df, output_file=frequencies_output_path
)

# Combined summary and sample
if not frequencies_df.empty:
    avg_coverage = frequencies_df["coverage_percent"].mean()
    high_coverage = (frequencies_df["coverage_percent"] > 50).sum()

    print("\nPattern Coverage Analysis:")
    print(f"   • Total patterns: {len(frequencies_df)}")
    print(f"   • Average coverage: {avg_coverage:.1f}%")
    print(f"   • High coverage (>50%): {high_coverage}")
    print(f"   • Exported to: {frequencies_output_path}")

    print("\nSample Coverage Data:")
    display(
        frequencies_df[["subject_class", "property", "object_class", "coverage_percent"]].head()
    )

    print("\nCoverage Statistics:")
    display(frequencies_df["coverage_percent"].describe())
else:
    print("No frequency data available")
# Out:
# Calculating schema pattern frequencies...
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_frequencies_basic.pkl
#
# Pattern Coverage Analysis:
#    • Total patterns: 96
#    • Average coverage: 58.3%
#    • High coverage (>50%): 56
#    • Exported to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_pattern_coverage.csv
#
# Sample Coverage Data:
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_frequencies_basic.pkl
#
# Pattern Coverage Analysis:
#    • Total patterns: 96
#    • Average coverage: 58.3%
#    • High coverage (>50%): 56
#    • Exported to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_pattern_coverage.csv
#
# Sample Coverage Data:
#                  subject_class                       property  \
# 79               aopo:KeyEvent                   rdfs:seeAlso
# 78  aopo:AdverseOutcomePathway                   rdfs:seeAlso
# 77   aopo:KeyEventRelationship                   rdfs:seeAlso
# 74   aopo:KeyEventRelationship  aopo:has_downstream_key_event
# 64              cheminf:000446               dcterms:isPartOf
#
#                   object_class  coverage_percent
# 79               aopo:KeyEvent             100.0
# 78  aopo:AdverseOutcomePathway             100.0
# 77   aopo:KeyEventRelationship             100.0
# 74               aopo:KeyEvent             100.0
# 64                 ncit:C54571             100.0
# Coverage Statistics:
# count     96.000000
# mean      58.343021
# std       39.700044
# min        0.060000
# 25%       12.905000
# 50%       70.425000
# 75%      100.000000
# max      100.000000
# Name: coverage_percent, dtype: float64

# %% [markdown]
# ## Schema Pattern Instance Collection
# Collect actual subject and object IRI instances for each schema pattern. This provides detailed access to the specific entities participating in each relationship pattern.

# %%
# Collect both frequency data and actual instances with caching
cache_key = f"{dataset_name}_frequencies_with_instances"
cached_data = load_cache(cache_key)

if cached_data is None:
    print("Collecting frequency data and instances...")
    frequencies_with_instances_df, instances_df = vp.count_schema_shape_frequencies(
        endpoint_url=endpoint_url,
        # sample_limit=100,  # Limited sample for demonstration
        collect_instances=True,
        offset_limit_steps=300,
    )
    # Cache both DataFrames as a tuple
    save_cache((frequencies_with_instances_df, instances_df), cache_key)
else:
    print("Loaded frequencies and instances DataFrames from cache")
    frequencies_with_instances_df, instances_df = cached_data

# Display basic information about the data structure
print(f"Frequencies DataFrame: {len(frequencies_with_instances_df)} shapes")
if instances_df is not None:
    print(f"Instances DataFrame: {len(instances_df)} subject-object pairs")
    print(
        f"Memory usage - Frequencies: {frequencies_with_instances_df.memory_usage(deep=True).sum() / 1024:.1f} KB"
    )
    print(f"Memory usage - Instances: {instances_df.memory_usage(deep=True).sum() / 1024:.1f} KB")
else:
    print("No instances collected")
# Out:
# Collecting frequency data and instances...
# 2025-11-26 13:51:59 INFO rdfsolve.parser: Total instances collected: 105304
# 2025-11-26 13:51:59 INFO rdfsolve.parser: Total instances collected: 105304
# INFO:rdfsolve.parser:Total instances collected: 105304
# Cached data to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/cache/aopwikirdf_frequencies_with_instances.pkl
# Frequencies DataFrame: 96 shapes
# Instances DataFrame: 105304 subject-object pairs
# Memory usage - Frequencies: 70.3 KB
# Memory usage - Instances: 19957.4 KB

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio

if not frequencies_df.empty:
    df = frequencies_df.copy()
    df["coverage_percent"] = pd.to_numeric(df["coverage_percent"], errors="coerce").fillna(0)
    df = df.sort_values("coverage_percent", ascending=False).reset_index(drop=True)

    def make_label(row):
        return (
            f"<b>{row['subject_class']}</b> "
            f"<span style='color:#888;'></span> "
            f"<i>{row['property']}</i> "
            f"<span style='color:#888;'></span> "
            f"<b>{row['object_class']}</b>"
        )

    df["styled_label"] = df.apply(make_label, axis=1)

    text_positions = ["outside" if v < 95 else "inside" for v in df["coverage_percent"]]
    custom_colorscale = [
        [0.0, "#d36e61"],
        [0.4, "#e5cdbd"],
        [0.7, "#e8e4cf"],
        [1.0, "#c3d9c0"],
    ]

    # Figure sizing
    bar_height = 26
    fig_height = min(2000, bar_height * len(df) + 200)

    fig = go.Figure(
        go.Bar(
            x=df["coverage_percent"],
            y=df["styled_label"],
            orientation="h",
            text=[f"{v:.1f}%" for v in df["coverage_percent"]],
            textposition=text_positions,
            marker={
                "color": df["coverage_percent"],
                "colorscale": custom_colorscale,
                "cmin": 0,
                "cmax": 100,
                "line": {"color": "white", "width": 0.6},
            },
            hovertemplate="<b>%{y}</b><br>Coverage: %{x:.1f}%<extra></extra>",
        )
    )

    fig.update_layout(
        title={
            "text": f"Schema Pattern Coverage for {dataset_name}",
            "x": 0.5,
            "font": {"size": 18},
        },
        xaxis={
            "title": "Coverage (%)",
            "range": [0, 100],  # fixed x-axis range
            "ticksuffix": "%",
            "showgrid": True,
            "gridcolor": "rgba(220,220,220,0.3)",
        },
        yaxis={
            "title": "",
            "autorange": "reversed",
            "automargin": True,
            "fixedrange": False,  # allow vertical zoom/pan
        },
        template="plotly_white",
        autosize=True,  # allow figure to scale with container
        height=fig_height,  # base height (will scale)
        margin={"t": 80, "b": 50, "l": 480, "r": 150},  # extra right margin for text
        plot_bgcolor="white",
        paper_bgcolor="white",
    )

    # Disable horizontal zoom/pan
    fig.update_xaxes(fixedrange=True)

    # Show figure with config for HTML export compatibility
    fig.show(
        config={
            "scrollZoom": True,
            "responsive": True,
            "toImageButtonOptions": {
                "format": "png",
                "filename": f"{dataset_name}_schema_coverage",
                "height": fig_height,
                "width": 600,
                "scale": 1,
            },
        }
    )

else:
    display(Markdown("**No coverage data to visualize**"))
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.2.0.min.js" integrity="sha256-iZ2u/oU2wf/vDbl/ChcX93WgbBRSBvUO6N413hDz7xM=" crossorigin="anonymous"></script>                <div id="27dc3376-17c6-4450-aaf5-f13955c2d8e6" class="plotly-graph-div" style="height:2000px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("27dc3376-17c6-4450-aaf5-f13955c2d8e6")) {                    Plotly.newPlot(                        "27dc3376-17c6-4450-aaf5-f13955c2d8e6",                        [{"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eCoverage: %{x:.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"cmax":100,"cmin":0,"color":{"dtype":"f8","bdata":"...\u002fC9SjcSUBcj8L1KNxJQOF6FK5HIUhA7FG4HoXLRkD2KFyPwrVFQBSuR+F6lERAcT0K16NQQEC4HoXrUXg\u002fQLgehetReD9ASOF6FK4HO0AUrkfhehQ6QBSuR+F6FDpAuB6F61F4OUDsUbgehWs3QOxRuB6FazdAexSuR+F6NUBI4XoUrgc1QDMzMzMzMypApHA9CtejKEC4HoXrUbgnQLgehetRuCdAXI\u002fC9ShcJ0ApXI\u002fC9SgnQD0K16NwPSFAPQrXo3A9IUCuR+F6FK4ZQK5H4XoUrhlArkfhehSuGUDhehSuR+EVQM3MzMzMzBBA7FG4HoXrDUAzMzMzMzMHQIXrUbgehfc\u002f7FG4HoXr9T\u002fNzMzMzMzwP6RwPQrXo\u002fA\u002fH4XrUbge7T\u002fNzMzMzMzsP3sUrkfheuQ\u002f9ihcj8L12D+kcD0K16PAP7gehetRuK4\u002f"},"colorscale":[[0.0,"#d36e61"],[0.4,"#e5cdbd"],[0.7,"#e8e4cf"],[1.0,"#c3d9c0"]],"line":{"color":"white","width":0.6}},"orientation":"h","text":["100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","100.0%","99.0%","99.0%","94.6%","94.6%","94.6%","94.6%","92.9%","92.9%","92.0%","90.9%","90.9%","89.5%","88.7%","86.8%","85.0%","83.6%","83.2%","83.2%","82.0%","82.0%","81.7%","71.3%","69.6%","56.1%","55.9%","55.9%","53.0%","53.0%","51.7%","51.7%","48.3%","45.6%","43.4%","41.2%","32.6%","31.5%","31.5%","27.0%","26.1%","26.1%","25.5%","23.4%","23.4%","21.5%","21.0%","13.1%","12.3%","11.9%","11.9%","11.7%","11.6%","8.6%","8.6%","6.4%","6.4%","6.4%","5.5%","4.2%","3.7%","2.9%","1.5%","1.4%","1.1%","1.0%","0.9%","0.9%","0.6%","0.4%","0.1%","0.1%"],"textposition":["inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","inside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside","outside"],"x":{"dtype":"f8","bdata":"...\u002fC9SjcSUBcj8L1KNxJQOF6FK5HIUhA7FG4HoXLRkD2KFyPwrVFQBSuR+F6lERAcT0K16NQQEC4HoXrUXg\u002fQLgehetReD9ASOF6FK4HO0AUrkfhehQ6QBSuR+F6FDpAuB6F61F4OUDsUbgehWs3QOxRuB6FazdAexSuR+F6NUBI4XoUrgc1QDMzMzMzMypApHA9CtejKEC4HoXrUbgnQLgehetRuCdAXI\u002fC9ShcJ0ApXI\u002fC9SgnQD0K16NwPSFAPQrXo3A9IUCuR+F6FK4ZQK5H4XoUrhlArkfhehSuGUDhehSuR+EVQM3MzMzMzBBA7FG4HoXrDUAzMzMzMzMHQIXrUbgehfc\u002f7FG4HoXr9T\u002fNzMzMzMzwP6RwPQrXo\u002fA\u002fH4XrUbge7T\u002fNzMzMzMzsP3sUrkfheuQ\u002f9ihcj8L12D+kcD0K16PAP7gehetRuK4\u002f"},"y":["\u003cb\u003encbitaxon:131567\u003c\u002fb\u003e \u003cspan style='color:#888;'\u003e\u003c\u002fspan\u003e \u003ci\u003edc:identifier\u003c\u002fi\u003e \u003cspan style='color:#888;'\u003e\u003c\u002fspan\u003e \u003cb\u003encbitaxon:131567\u003c\u002fb\u003e","\u0 ...

# %% [markdown]
# ## LinkML (derived from JSON-LD)

# %%
# Generate LinkML directly from JSON-LD with custom schema URI
print("Regenerating LinkML schema from JSON-LD with custom schema URI...")

schema_name = f"{dataset_name}_schema"
custom_schema_uri = (
    f"http://jmillanacosta.github.io/rdfsolve/{dataset_name}/linkml"  # User-definable base URI
)

yaml_text = vp.to_linkml_yaml(
    schema_name=schema_name,
    schema_description=f"LinkML schema for {dataset_name} generated from JSON-LD",
    schema_base_uri=custom_schema_uri,
    filter_void_nodes=True,
)

# Save to LinkML YAML
linkml_file = os.path.join(exports_path, f"{dataset_name}_linkml_schema.yaml")
with open(linkml_file, "w", encoding="utf-8") as f:
    f.write(yaml_text)

print(f"LinkML YAML saved to: {linkml_file}")
# Out:
# Regenerating LinkML schema from JSON-LD with custom schema URI...
# LinkML YAML saved to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_linkml_schema.yaml
# LinkML YAML saved to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_linkml_schema.yaml

# %%
from linkml.generators.erdiagramgen import ERDiagramGenerator
from linkml_runtime.utils.schemaview import SchemaView

sv = SchemaView(linkml_file)
linkml_schema = sv.schema

display(
    Markdown(
        f"**Parsed LinkML schema:** Classes = {len(sv.all_classes())}, Slots = {len(sv.all_slots())}"
    )
)

# Build and display a Mermaid class diagram for the aopwikirdf LinkedML
mermaid_code = ERDiagramGenerator(linkml_file).serialize()

display(Markdown(mermaid_code))
# Out:
# **Parsed LinkML schema:** Classes = 19, Slots = 23
# ```mermaid
# erDiagram
# AopoAdverseOutcomePathway {
#
# }
# AopoBiologicalEvent {
#
# }
# AopoCellTypeContext {
#
# }
# AopoKeyEvent {
#
# }
# AopoKeyEventRelationship {
#
# }
# AopoOrganContext {
#
# }
# Cheminf000000 {
#
# }
# Cheminf000405 {
#
# }
# Cheminf000446 {
#
# }
# EdamData1025 {
#
# }
# EdamData1027 {
#
# }
# EdamData2291 {
#
# }
# EdamData2298 {
#
# }
# Go0008150 {
#
# }
# Ncbitaxon131567 {
#
# }
# NcitC54571 {
#
# }
# Pato0001241 {
#
# }
# VoidDataset {
#
# }
# VoidLinkset {
#
# }
#
# AopoAdverseOutcomePathway ||--|o AopoAdverseOutcomePathway : "rdfs_see_Also"
# AopoAdverseOutcomePathway ||--|o AopoKeyEvent : "aopo_has_adverse_outcome"
# AopoAdverseOutcomePathway ||--|o AopoKeyEvent : "aopo_has_key_event"
# AopoAdverseOutcomePathway ||--|o AopoKeyEvent : "aopo_has_molecular_initiating_event"
# AopoAdverseOutcomePathway ||--|o AopoKeyEventRelationship : "aopo_has_key_event_relationship"
# AopoAdverseOutcomePathway ||--|o Ncbitaxon131567 : "dc_identifier"
# AopoAdverseOutcomePathway ||--|o NcitC54571 : "foaf_page"
# AopoAdverseOutcomePathway ||--|o NcitC54571 : "has_ncit_C_54571"
# AopoBiologicalEvent ||--|o Go0008150 : "aopo_has_Object"
# AopoBiologicalEvent ||--|o Pato0001241 : "aopo_has_Process"
# AopoCellTypeContext ||--|o Ncbitaxon131567 : "dc_identifier"
# AopoKeyEvent ||--|o AopoAdverseOutcomePathway : "rdfs_see_Also"
# AopoKeyEvent ||--|o AopoBiologicalEvent : "aopo_has_Biological_Event"
# AopoKeyEvent ||--|o EdamData2298 : "has_edam_data_1025"
# AopoKeyEvent ||--|o Go0008150 : "has_pato_0001241"
# AopoKeyEvent ||--|o Ncbitaxon131567 : "dc_identifier"
# AopoKeyEvent ||--|o Ncbitaxon131567 : "has_ncbitaxon_131567"
# AopoKeyEvent ||--|o NcitC54571 : "dcterms_is_Part_Of"
# AopoKeyEvent ||--|o NcitC54571 : "foaf_page"
# AopoKeyEvent ||--|o Pato0001241 : "has_aopo_Cell_Type_Context"
# AopoKeyEvent ||--|o Pato0001241 : "has_aopo_Organ_Context"
# AopoKeyEvent ||--|o Pato0001241 : "has_go_0008150"
# AopoKeyEventRelationship ||--|o AopoAdverseOutcomePathway : "rdfs_see_Also"
# AopoKeyEventRelationship ||--|o AopoKeyEvent : "aopo_has_downstream_key_event"
# AopoKeyEventRelationship ||--|o AopoKeyEvent : "aopo_has_upstream_key_event"
# AopoKeyEventRelationship ||--|o EdamData2298 : "has_edam_data_1025"
# AopoKeyEventRelationship ||--|o Ncbitaxon131567 : "dc_identifier"
# AopoKeyEventRelationship ||--|o NcitC54571 : "dcterms_is_Part_Of"
# AopoKeyEventRelationship ||--|o NcitC54571 : "foaf_page"
# AopoOrganContext ||--|o Ncbitaxon131567 : "dc_identifier"
# Cheminf000000 ||--|o EdamData2291 : "skos_exact_Match"
# Cheminf000000 ||--|o Ncbitaxon131567 : "dc_identifier"
# Cheminf000000 ||--|o NcitC54571 : "dcterms_is_Part_Of"
# Cheminf000446 ||--|o EdamData2291 : "skos_exact_Match"
# Cheminf000446 ||--|o Ncbitaxon131567 : "dc_identifier"
# Cheminf000446 ||--|o NcitC54571 : "dcterms_is_Part_Of"
# EdamData1025 ||--|o EdamData2291 : "skos_exact_Match"
# EdamData2298 ||--|o EdamData2291 : "skos_exact_Match"
# Go0008150 ||--|o Ncbitaxon131567 : "dc_identifier"
# Ncbitaxon131567 ||--|o Ncbitaxon131567 : "dc_identifier"
# NcitC54571 ||--|o Cheminf000446 : "aopo_has_chemical_entity"
# NcitC54571 ||--|o Ncbitaxon131567 : "dc_identifier"
# NcitC54571 ||--|o NcitC54571 : "dcterms_is_Part_Of"
# NcitC54571 ||--|o NcitC54571 : "foaf_page"
# Pato0001241 ||--|o EdamData2291 : "skos_exact_Match"
# Pato0001241 ||--|o Ncbitaxon131567 : "dc_identifier"
# VoidDataset ||--|o VoidDataset : "dcat_download_URL"
# VoidLinkset ||--|o VoidDataset : "dcat_download_URL"
#
# ```

# %%
json_path = os.path.join(exports_path, f"{dataset_name}_schema.json")
csv_path = os.path.join(exports_path, f"{dataset_name}_schema.csv")

# Export CSV from frequencies
frequencies_df.to_csv(csv_path, index=False)

# Export JSON derived from JSON-LD (maintains consistency)
with open(json_path, "w", encoding="utf-8") as fh:
    json.dump(vp.to_json(filter_void_nodes=True), fh, indent=2)

print(f"CSV exported to: {csv_path}")
print(f"JSON exported to: {json_path}")
# Out:
# CSV exported to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_schema.csv
# JSON exported to: /home/javi/rdfsolve-1/notebooks/01_schema_extraction/../../docs/data/schema_extraction/aopwikirdf/aopwikirdf_schema.json
